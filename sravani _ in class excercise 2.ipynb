# %% [markdown]
# ## The third In-class-exercise (02/08/2022, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):


#Research Question:

"""While thinking about how to answer the exercise question, I was just listening to music, and after a few hours of 
contemplating what topic I should choose for the exercise, I thought to myself, "Why don't I get the data of all the
most streamed Albums on Spotify (a music streaming service) for over a decade?"""

#Data needed

"""All I required was a list of all the albums that had the most streams and by which artists, as well as the number of streams in millions. 
On top of that, I started collecting the album's release date and year."""

#Methodology
"""
The first thing I did was import the urllib3 module in order to get the appropriate URL.
The second step is to send the request to open the URL using the urllib. request module.
The next step is to set up a lovely soup library so that you can quickly scrape the data."""

#Result
"""Finally, the output is displayed in the form of a table which fields like Rank, Name of  Artists who has the highest streamed songs, Stream in Millions, Name of the Album, and Published year.
""
# Out:
#   File "<ipython-input-4-aa8a7ef24258>", line 24
#
#     ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):
import urllib.request
#Reading the url or url from which the data is being extracted 
sample_data= "https://en.wikipedia.org/wiki/List_of_most-streamed_songs_on_Spotify"
#Using the urllib module for sending request for opening the url 
p = urllib.request.urlopen(sample_data)
#Using the beautiful soup to extract the datat from the webpage
from bs4 import BeautifulSoup
s = BeautifulSoup(p)
#petrify function is being used to know the detail structure of html page 
print(s.prettify())
all_tables=s.find_all('table')
#We have extarcted all the tables in the page but to extra the specific data we are using the specif class of that table.
table_right=s.find('table', class_='wikitable sortable')
table_right
data_total = []

for i in table_right.findAll("tr"):
    j = i.findAll('td')
    songs_spotiffy=i.findAll('th')
    if len(j)==5: #Only extract table body not heading
      list1= []
      list1.append(songs_spotiffy[0].find(text=True).strip("\n"))
      list1.append(j[1].find(text=True).strip("\n"))
      list1.append(j[2].find(text=True).strip("\n"))
      list1.append(j[3].find(text=True).strip("\n"))
      list1.append(j[4].find(text=True).strip("\n"))
      #item.append(cells[5].find(text=True).strip("\n"))
      data_total.append(item)
print(data_total)

all_new_clear_data = []


heading = ['Rank','Artists(s)','Alubum','stream in millions','Date Published']

for i in data_total:
  record_dict = dict(zip(heading,i))
  all_new_clear_data.append(record_dict)
print(all_new_clear_data)

Ranking=[]
Artists=[]
Album=[]
Stream=[]
Date=[]
for row in table_right.findAll("tr"):
    cells = row.findAll('td')
    songs=row.findAll('th')
    if len(cells)==5: 
        Ranking.append(songs[0].find(text=True).strip("\n"))
        Artists.append(cells[1].find(text=True).strip("\n"))
        Album.append(cells[2].find(text=True).strip("\n"))
        Stream.append(cells[3].find(text=True).strip("\n"))
        Date.append(cells[4].find(text=True).strip("\n"))
        
print(Ranking)
print(Artists)
print(Album)
print(Stream)
print(Date)

#converting list into dataframe

import pandas as pd
df=pd.DataFrame(Ranking,columns=['Rank'])
df['Artist(s)']=Artists
df['Albums']=Album
df['Stream in Millions']=Stream
df['Date of Publish']=Date
df
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    List of most-streamed songs on Spotify - Wikipedia
#   </title>
#   <script>
# ...

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
# You code here (Please add comments in the code):

from bs4 import BeautifulSoup
import requests, lxml, os, json
import pandas as pd
headers = {
    'User-agent':
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
}
params = {
  "q": "Information Science",
  "hl": "en",
}
link_google = requests.get('https://scholar.google.com/scholar', headers=headers, params = params).text
s = BeautifulSoup(link_google, 'lxml')
for i in s.select('.gs_or_ggsm a'):
  link = i['href']
  print(link)
  data= []
for j in s.select('.gs_ri'):
  title_header = j.select_one('.gs_rt').text
  Information_publication = j.select_one('.gs_a').text
  abstract = j.select_one('.gs_rs').text
  try:
    version_of_articles = result.select_one('a~ a+ .gs_nph')['href']
  except:
    version_of_articles = None
  d = {
      'Title': title_header,
      'Authors/Venue/journal/conference being published/Year': Information_publication,
      'Abstract': abstract
  }
  list_of_data.append(d)
df = pd.DataFrame(list_of_data)
df.head()
# Out:
# https://www.marilia.unesp.br/Home/Instituicao/Docentes/EdbertoFerneda/k---artigo-01.pdf
# http://library.tuit.uz/knigiPDF/ang/5-606.pdf
# https://discovery.ucl.ac.uk/id/eprint/10053533/3/Longley_version%202.0_Manfred%20geocomp_PAL.pdf
# https://www.academia.edu/download/30771284/relevanceSaracevic.pdf
# http://citeseerx.ist.psu.edu/viewdoc/download?doi=10.1.1.590.5487&rep=rep1&type=pdf
#                                                Title  \
# 0                   Information science: what is it?
# 1       Information concepts for information science
# 2  The foundations of information science. Part I...
# 3  [BOOK][B] Foundations of library and informati...
# 4                   Geographical information science
#
#   Authors/Venue/journal/conference being published/Year  \
# 0  H Borko - American documentation, 1968 - Wiley...
# 1  NJ Belkin - Journal of documentation, 1978 - e...
# 2  BC Brookes - Journal of information science, 1...
# ...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
# You code here (Please add comments in the code):
