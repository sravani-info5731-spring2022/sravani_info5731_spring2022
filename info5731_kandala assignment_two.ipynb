# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source via web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (40 points). Write a python program to collect text data from **either of the following sources** and save the data into a **csv file**:
#
# (1) Collect all the customer reviews of the product [Apple iPhone 11](https://www.amazon.com/Apple-iPhone-11-64GB-Unlocked/dp/B07ZPKF8RG/ref=sr_1_13?dchild=1&keywords=iphone+12&qid=1631721363&sr=8-13) on amazon.
#
# (2) Collect the top 10000 User Reviews of the film [Shang-Chi and the Legend of the Ten Rings](https://www.imdb.com/title/tt9376612/reviews?ref_=tt_sa_3) from IMDB.
#
# (3) Collect all the reviews of the top 100 most popular software from [G2](https://www.g2.com/) or [Capterra](https://www.capterra.com/)
#
# (4) Collect the abstracts of the top 10000 research papers by using the query [natural language processing](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlv&t=doc) from CiteSeerX.
#
# (5) Collect all the information of the 904 narrators in the [Densho Digital Repository](https://ddr.densho.org/narrators/).
#
# (6) Collect the top 10000 tweets by using hashtag ["#blacklivesmatter"](https://twitter.com/hashtag/blacklivesmatter) from Twitter.

# %%
    MovieSoup = self.get_movie_soup(self.moviesLink[0])
    reviews_list = self.get_reviews(MovieSoup)
    for k in reviews_list:
      imdbReview.append(self.get_review_text(k))
    userList = []
    for j in reviews_list:
      userList.append(self.user_name(j))
    ratings = []
    for x in reviews_list:
      ratings.append(self.Ratings(x))
    dates = []
    for i in reviews_list:
      dates.append(self.getReviewPostedDate(i))

    data = {'User_Name': userList, 'Review_text': imdbReview, 'Review_posted_time': dates, 'Star': ratings}
    dataframe = pandas.DataFrame(data)
    dataframe.head()
    return dataframe

  def get_movie_soup(self, web_link):
    data = requests.get(web_link)
    movie_soup = BeautifulSoup(data.text, 'html.parser')
    return movie_soup

  def Ratings(self, review):    
    temp = self.get_movie_soup(review)
    movie_tag = temp.find('div', attrs={'class': 'ipl-ratings-bar'})
    return list(movie_tag.children)[1].getText()
 
  def get_review_text(self, web_link):
    soup = self.get_movie_soup(web_link)
    tag = soup.find('div', attrs={'class':'text show-more__control'})
    self.get_movie_review = tag.getTimport pandas
import requests
import numpy
from bs4 import BeautifulSoup
import re
import lxml.html as LH
import itertools

class collect_to_CSV:
  def __init__(self):
      self.moviesList = []
      self.moviesLink = []
      self.movie_tag = None
      self.get_movie_review = None

  def call_all_functions(self):
    imdbReview = []ext()

  def mini_max(self, var):
      print(len(var))
      min_position = var.index(min(var))
      max_position = var.index(max(var))
      return min_position, max_position


  def get_reviews(self, movieSoup):
    reviewRate = []
    for i in movieSoup.find_all('span', attrs={'class': 'point-scale'}):
      reviewRate.append(i.previous_element)
    if len(reviewRate) > 0:
      self.mini_max(list(map(int, reviewRate)))
      reviewsList = movieSoup.find_all('a', attrs={'class':'title'})
      reviews = []
      for x in reviewsList:
        reviews.append("https://www.imdb.com" + x['href'])
      return reviews
    else:
      return None
    

  def collect_data_from_url(self):
    titles = 'https://www.imdb.com/title/tt9376612/reviews?ref_=tt_sa_3'
    main_url = "https://www.imdb.com"
    data = requests.get(titles)
    movies_Soup = BeautifulSoup(data.text, 'lxml')
    movieTags = movies_Soup.find_all('a', attrs = {'class': None})
    for i in range(len(movieTags)):
      if movieTags[i].attrs['href'].startswith('/title') & movieTags[i].attrs['href'].endswith('/'):
        self.moviesList.append(movieTags[i].attrs['href'])
    self.moviesList = list(dict.fromkeys(self.moviesList))
    for j in range(len(self.moviesList)):
      temp = main_url + self.moviesList[j] + 'reviews'
      self.moviesLink.append(temp)


  def user_name(self, review):
    temp = self.get_movie_soup(review)
    movieTag = temp.find('h3')
    return list(movieTag.children)[0].getText() 

obj = collect_to_CSV()
obj.collect_data_from_url()
dataframe = obj.call_all_functions()
# Out:
#   File "<ipython-input-4-ddc35b76dad4>", line 20
#     def get_movie_soup(self, web_link):
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points). Write a python program to **clean the text data** you collected above and save the data in a new column in the csv file. The data cleaning steps include:
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the [stopwords list](https://gist.github.com/sebleier/554280).
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
import nltk
import pandas
from nltk.corpus import stopwords
import nltk
from textblob import TextBlob, Word
from nltk.stem import PorterStemmer

# %%
# Lower casing words
df['Lower'] = df['Legal_records'].apply(lambda k: " ".join(k.lower() for k in k.split()))
print(df[['Legal_records','Lower']].head())
# Out:
#                                        Legal_records                                              Lower
# 0  5 ala 740 supreme alabama adamsvtanner horton ...  5 ala 740 supreme alabama adamsvtanner horton ...
# 1                 synopsis writ error circuit sumter                 synopsis writ error circuit sumter
# 2                                   west headnotes 2                                   west headnotes 2
# 3                             1chattel mortgage crop                             1chattel mortgage crop
# 4  existence subjectmatter mortgage contract pas ...  existence subjectmatter mortgage contract pas ...

# %%
# Remove punctuation
df['Legal_records'] = df['Legal_records'].str.replace('[^\w\s]','')
print(df['Legal_records'].head())
# Out:
# 0    5 ala 740 supreme alabama adamsvtanner horton ...
# 1                   synopsis writ error circuit sumter
# 2                                     west headnotes 2
# 3                               1chattel mortgage crop
# 4    existence subjectmatter mortgage contract pas ...
# Name: Legal_records, dtype: object

# %%
# Remove stopwords
df['Legal_records'] = df['Legal_records'].apply(lambda x: " ".join(x for x in x.split() if x not in stopwords.words('english')))
print(df['Legal_records'].head())
# Out:
# 0    5 ala 740 supreme alabama adamsvtanner horton ...
# 1                   synopsis writ error circuit sumter
# 2                                     west headnotes 2
# 3                               1chattel mortgage crop
# 4    existence subjectmatter mortgage contract pas ...
# Name: Legal_records, dtype: object

# %%
# Frequent words removal 
frequent_words = pandas.Series(' '.join(df['Legal_records']).split()).value_counts()[:10]
print(frequent_words)
# Out:
# case          16
# rep           16
# contract      16
# plaintiff     15
# law           15
# cotton        14
# possession    13
# time          12
# sale          12
# defendant     12
# dtype: int64

# %%
df['Legal_records'] = df['Legal_records'].apply(lambda k: " ".join(k for k in k.split() if k not in frequent_words))
print(df['Legal_records'].head())
# Out:
# 0    5 ala 740 supreme alabama adamsvtanner horton ...
# 1                   synopsis writ error circuit sumter
# 2                                     west headnotes 2
# 3                               1chattel mortgage crop
# 4    existence subjectmatter mortgage contract pas ...
# Name: Legal_records, dtype: object

# %%
df['Legal_records'] = df['Legal_records'].apply(lambda k: " ".join(k for k in k.split() if k not in frequent_words))
df['Legal_records'].head()
# Out:
# 0    5 ala 740 supreme alabama adamsvtanner horton ...
# 1                   synopsis writ error circuit sumter
# 2                                     west headnotes 2
# 3                               1chattel mortgage crop
# 4    existence subjectmatter mortgage contract pas ...
# Name: Legal_records, dtype: object

# %%
# Stemming
stemming = PorterStemmer()
df['Legal_records'][:5].apply(lambda k: " ".join([stemming.stem(word) for word in k.split()]))
# Out:
# 0    5 ala 740 suprem alabama adamsvtann horton jun...
# 1                    synopsi writ error circuit sumter
# 2                                       west headnot 2
# 3                                1chattel mortgag crop
# 4    exist subjectmatt mortgag contract pa interest...
# Name: Legal_records, dtype: object

# %%
# Lemmatization 
nltk.download('wordnet')
df['Legal_records'] = df['Legal_records'].apply(lambda k: " ".join([Word(j).lemmatize() for j in k.split()]))
print(df['Legal_records'].head())
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# 0    5 ala 740 supreme alabama adamsvtanner horton ...
# 1                   synopsis writ error circuit sumter
# 2                                     west headnotes 2
# 3                               1chattel mortgage crop
# 4    existence subjectmatter mortgage contract pa i...
# Name: Legal_records, dtype: object

# %%
# Save all the clean sentences to a csv file 
df.to_csv("LegalRecords_output.csv")

# %%
term_frequent = (df['Legal_records'][1:2]).apply(lambda i: pandas.value_counts(i.split(" "))).sum(axis = 0).reset_index()
term_frequent.columns = ['words','termfreq']
print(term_frequent)
# Out:
#       words  termfreq
# 0    sumter         1
# 1   circuit         1
# 2     error         1
# 3      writ         1
# 4  synopsis         1

# %%
#2-gram
num_gram = TextBlob(train['Legal_records'][0]).num_gram(2)
print(num_gram[:10])
# Out:
# [WordList(['5', 'ala']),
#  WordList(['ala', '740']),
#  WordList(['740', 'supreme']),
#  WordList(['supreme', 'alabama']),
#  WordList(['alabama', 'adamsvtanner']),
#  WordList(['adamsvtanner', 'horton']),
#  WordList(['horton', 'june']),
#  WordList(['june', 'term']),
#  WordList(['term', '1843'])]

# %% [markdown]
# # **Question 3**

# %% [markdown]
# (30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just saved above. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) Tagging: Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
#Parts of Speech (POS) Tagging 
import spacy
import spacy.cli
nltk.download('punkt')
from spacy import displacy
from nltk import word_tokenize, pos_tag, pos_tag_sents
from collections import Counter
from nltk.tokenize import word_tokenize
import en_core_web_sm
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
# Taging each parts of speech in the text
total_parts_of_speech = []
for k in df['Lower']:
  word = word_tokenize(k)
  total_parts_of_speech.append(nltk.pos_tag(word))
print(total_parts_of_speech)
# Out:
# [[('5', 'CD'),
#   ('ala', 'JJ'),
#   ('740', 'CD'),
#   ('supreme', 'JJ'),
#   ('alabama', 'NN'),
#   ('adamsvtanner', 'NN'),
#   ('horton', 'NN'),
#   ('june', 'NN'),
#   ('term', 'NN'),
#   ('1843', 'CD')],
#  [('synopsis', 'NN'),
#   ('writ', 'NN'),
#   ('error', 'NN'),
#   ('circuit', 'NN'),
#   ('sumter', 'NN')],
#  [('west', 'NN'), ('headnotes', 'VBZ'), ('2', 'CD')],
#  [('1chattel', 'CD'), ('mortgage', 'NN'), ('crop', 'NN')],
#  [('existence', 'NN'),
#   ('subjectmatter', 'NN'),
#   ('mortgage', 'NN'),
#   ('contract', 'NN'),
#   ('pas', 'JJ'),
#   ('interest', 'NN'),
#   ('vest', 'NN'),
#   ('possession', 'NN'),
#   ('either', 'CC'),
#   ('immediately', 'RB'),
#   ('future', 'JJ'),
#   ('time', 'NN')],
#  [('4', 'CD'), ('case', 'NN'), ('cite', 'JJ'), ('headnote', 'NN')],
#  [('4', 'CD'), ('case', 'NN'), ('cite', 'JJ'), ('headnote', 'NN')],
#  [('2', 'CD'), ('creditor', 'NN'), ('remedy', 'NN'), ('priority', 'NN')],
#  [('st1821', 'NN'),
#   ('attache', 'NN'),
# ...

# %%
# Compute total number of Noun, Adverb, Verb, Adjective
def compute_POS(total_parts_of_speech):
  temp = []
  for x in total_parts_of_speech:
    tot_count = Counter(k for j, k in x)
    temp.append(tot_count)
  return temp
print(compute_POS(total_parts_of_speech))
# Out:
# [Counter({'CD': 3, 'JJ': 2, 'NN': 5}),
#  Counter({'NN': 5}),
#  Counter({'CD': 1, 'NN': 1, 'VBZ': 1}),
#  Counter({'CD': 1, 'NN': 2}),
#  Counter({'CC': 1, 'JJ': 2, 'NN': 8, 'RB': 1}),
#  Counter({'CD': 1, 'JJ': 1, 'NN': 2}),
#  Counter({'CD': 1, 'JJ': 1, 'NN': 2}),
#  Counter({'CD': 1, 'NN': 3}),
#  Counter({'CD': 1, 'JJ': 1, 'NN': 6, 'RB': 1, 'VBD': 1}),
#  Counter({'CD': 1, 'JJ': 1, 'NN': 2}),
#  Counter({'CD': 6,
#           'IN': 1,
#           'JJ': 10,
#           'NN': 36,
#           'NNS': 4,
#           'RB': 3,
#           'VB': 1,
#           'VBD': 8,
#           'VBG': 1,
#           'VBN': 8,
#           'VBP': 3}),
#  Counter({'CD': 6,
#           'IN': 2,
#           'JJ': 8,
#           'MD': 1,
#           'NN': 29,
#           'NNS': 1,
#           'RB': 3,
#           'RBR': 1,
#           'VB': 1,
#           'VBD': 8,
#           'VBG': 3,
#           'VBN': 5,
#           'VBZ': 1}),
#  Counter({'IN': 1, 'JJ': 2, 'NN': 6, 'VBD': 3, 'VBN': 2}),
# ...

# %%
 # !pip install benepar
# Out:
# ...
#      |████████████████████████████████| 6.5 MB 23.6 MB/s
# ...
#      |████████████████████████████████| 3.5 MB 57.2 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 40.9 MB/s
# ...
#      |████████████████████████████████| 596 kB 40.9 MB/s
# ...
#      |████████████████████████████████| 895 kB 46.1 MB/s
# ...
#      |████████████████████████████████| 67 kB 4.5 MB/s
# ...
#   Created wheel for benepar: filename=benepar-0.2.0-py3-none-any.whl size=37647 sha256=4d2c312f7378fa60b3f0b07c12d91a4da639f5ffa13655eadbea3e0acb7229b7
#   Stored in directory: /root/.cache/pip/wheels/dc/6f/a3/4d27ce92766bdedd2cbbbedb8857fb7a53534331191cda4994
# Successfully built benepar
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# %tensorflow_version 1.x
import benepar
benepar.download('benepar_en3')
parser=benepar.Parser("benepar_en3")
# Out:
# TensorFlow 1.x selected.
# [nltk_data] Downloading package benepar_en3 to /root/nltk_data...
# [nltk_data]   Unzipping models/benepar_en3.zip.

# %%
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
pip install tensorflow == 2.4
# Out:
# ...
#      |████████████████████████████████| 394.7 MB 12 kB/s
# ...
#      |████████████████████████████████| 14.8 MB 48.0 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 41.4 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 39.1 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 41.5 MB/s
# ...
#      |████████████████████████████████| 462 kB 74.6 MB/s
# ...
#      |████████████████████████████████| 132 kB 74.1 MB/s
# ...
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp37-cp37m-linux_x86_64.whl size=68718 sha256=3f7dc338c7bd4d94695a6e0d4ec772c479003c1fbabc2db8819bd3ae2d4d30bb
#   Stored in directory: /root/.cache/pip/wheels/62/76/4c/aa25851149f3f6d9785f6c869387ad82b3fd37582fa8147ac6
# Successfully built wrapt
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: numpy
# ...

# %%
for text in df['Converting into LowerCase']: 
   try:
     dependency_tree = parser.parse(text)
     print(dependency_tree)
   except:
     print("No Parse Tree")
     continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a8792b8d828f> in <module>()
# ----> 1 for text in df['Converting into LowerCase']:
#       2    try:
#       3      dependency_tree = parser.parse(text)
#       4      print(dependency_tree)
#       5    except:
#
# NameError: name 'df' is not defined

# %%
# Dependency Parsing
spacy.cli.download("en_core_web_sm")
# Out:
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')

# %%
var = benepar.Parser("benepar_en")
for text in df['Lower']: 
   try:
     dependency_tree = var.parse(text)
     print(dependency_tree)
   except:
     print("No Parse Tree")
     continue
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-39af292d89cc> in <module>
# ----> 1 var = benepar.Parser("benepar_en")
#       2 for text in df['Lower']:
#       3    try:
#       4      dependency_tree = var.parse(text)
#       5      print(dependency_tree)
#
# NameError: name 'benepar' is not defined

# %%
# Entity Recognition
nlp = en_core_web_sm.load()
for word in df['Lower']:
  word_doc = nlp(word)
  for k in word_doc.ents:
    if k.text and k.label_:
      print([(k.text, k.label_)])
# Out:
# [('5', 'CARDINAL')]
# [('740', 'CARDINAL')]
# [('supreme alabama adamsvtanner', 'ORG')]
# [('june term 1843', 'DATE')]
# [('synopsis writ error circuit', 'ORG')]
# [('west headnotes 2', 'ORG')]
# [('1chattel', 'CARDINAL')]
# [('4', 'CARDINAL')]
# [('4', 'CARDINAL')]
# [('2', 'CARDINAL')]
# [('5', 'CARDINAL')]
# [('5', 'CARDINAL')]
# [('1', 'CARDINAL')]
# [('november 1840', 'DATE')]
# [('allen harrison', 'PERSON')]
# [('thirty', 'CARDINAL')]
# [('allen harrison', 'PERSON')]
# [('october 1839', 'DATE')]
# [('741', 'CARDINAL')]
# [('thereon 7th', 'ORG')]
# [('may 1840', 'DATE')]
# [('indorser burton harrison', 'PERSON')]
# [('fourteen thousand dollar', 'MONEY')]
# [('one hundred twenty acre', 'QUANTITY')]
# [('allen harrison', 'PERSON')]
# [('gainesville tennessee', 'PERSON')]
# [('first', 'ORDINAL')]
# [('september 1840', 'DATE')]
# [('three four', 'CARDINAL')]
# [('first', 'ORDINAL')]
# [('1840', 'DATE')]
# [('2', 'CARDINAL')]
# [('1', 'CARDINAL')]
# [('361', 'CARDINAL')]
# ...

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %% [markdown]
# **Constituency parsing tree:** Constituency parsing tree is a process of breaking texts into sub-phrases or sub-texts called as constituients. It is also called as syntactical parsing which defines structure of a sentence. The sub phrases belongs to grammar of Noun Phase and verb phrase.
#
# **Dependency Parsing Tree:**
# It is a process of understanding the gramatical structure of a sentence that depends on dependencies between words in a sentence. It helps us build parsing trees with tags
